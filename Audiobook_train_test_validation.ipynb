# %% [markdown]
# <a href="https://colab.research.google.com/github/kirat89/Google_colab/blob/main/Audiobook_train_test_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## loading dataset

# %%
raw_data=pd.read_csv('Audiobooks_data.csv')
raw_inputs=raw_data.iloc[:,1:-1].values
targets=raw_data.iloc[:,-1].values

# %% [markdown]
# ## shuffle

# %%
## since data maybe date biased so we try to randomise the data
indices=np.arange(raw_inputs.shape[0])
np.random.shuffle(indices)

shuffled_inputs=raw_inputs[indices]
shuffled_targets=targets[indices]

# %% [markdown]
# ## balancing

# %%
#the customer not purchasing(0) are much more than customer purchasing(1)
#so we balance the dataset to keep the learning effecient

#getting the no of purchases(1)
num_one_target= int(np.sum(targets))
#setting a zero counter
zero_counter=0
#after balance the extra data to be removed will be removed using this list
indices_to_remove=[]

for i in range(shuffled_targets.shape[0]):
  if shuffled_targets[i]==0:
    zero_counter+=1
    if zero_counter>num_one_target:
      indices_to_remove.append(i)

balanced_inputs=np.delete(shuffled_inputs,indices_to_remove,axis=0)
balanced_targets=np.delete(shuffled_targets,indices_to_remove,axis=0)

# %%
#Balancing yet again before train test validation split
indices=np.arange(balanced_inputs.shape[0])
np.random.shuffle(indices)

balanced_inputs=balanced_inputs[indices]
balanced_targets=balanced_targets[indices]

# %% [markdown]
# ## train_test_validation_split

# %%
samples_count=(balanced_inputs.shape[0])
train_count= int(.8*samples_count)
validation_count= int(.1*samples_count)
test_count=samples_count-(train_count+validation_count)

train_inputs=balanced_inputs[:train_count]
train_targets=balanced_targets[:train_count]

validation_inputs=balanced_inputs[train_count:train_count+validation_count]
validation_targets=balanced_targets[train_count:train_count+validation_count]

test_inputs=balanced_inputs[train_count+validation_count:]
test_targets=balanced_targets[train_count+validation_count:]

# %%
print(np.sum(train_targets),train_count,np.sum(train_targets)/train_count)
print(np.sum(validation_targets),validation_count,np.sum(validation_targets)/validation_count)
print(np.sum(test_targets),test_count,np.sum(test_targets)/test_count)
# Out:
# 1793 3579 0.5009779267951942
# 222 447 0.4966442953020134
# 222 448 0.4955357142857143

# %% [markdown]
# ## Standarizing the data

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
train_inputs=ss.fit_transform(train_inputs)
test_inputs=ss.transform(test_inputs)
validation_inputs=ss.transform(validation_inputs)

# %% [markdown]
# ## deep learning model

# %%
import tensorflow as tf
ann=tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=50,activation='relu'))
ann.add(tf.keras.layers.Dense(units=50,activation='relu'))
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
ann.compile(optimizer='adam' ,loss='binary_crossentropy' ,metrics=['accuracy'])

# %%
ann.fit(train_inputs,train_targets,batch_size=32,epochs=100, validation_data=(validation_inputs,validation_targets),verbose=2)
# Out:
# Epoch 1/100
# 112/112 - 1s - loss: 0.5324 - accuracy: 0.7234 - val_loss: 0.4276 - val_accuracy: 0.7919
# Epoch 2/100
# 112/112 - 0s - loss: 0.4159 - accuracy: 0.7840 - val_loss: 0.3843 - val_accuracy: 0.7987
# Epoch 3/100
# 112/112 - 0s - loss: 0.3844 - accuracy: 0.8011 - val_loss: 0.3681 - val_accuracy: 0.8098
# Epoch 4/100
# 112/112 - 0s - loss: 0.3726 - accuracy: 0.8022 - val_loss: 0.3614 - val_accuracy: 0.8233
# Epoch 5/100
# 112/112 - 0s - loss: 0.3648 - accuracy: 0.8027 - val_loss: 0.3645 - val_accuracy: 0.8143
# Epoch 6/100
# 112/112 - 0s - loss: 0.3581 - accuracy: 0.8069 - val_loss: 0.3513 - val_accuracy: 0.8277
# Epoch 7/100
# 112/112 - 0s - loss: 0.3586 - accuracy: 0.8080 - val_loss: 0.3538 - val_accuracy: 0.8166
# Epoch 8/100
# 112/112 - 0s - loss: 0.3506 - accuracy: 0.8108 - val_loss: 0.3485 - val_accuracy: 0.8188
# Epoch 9/100
# 112/112 - 0s - loss: 0.3474 - accuracy: 0.8167 - val_loss: 0.3520 - val_accuracy: 0.8277
# Epoch 10/100
# 112/112 - 0s - loss: 0.3462 - accuracy: 0.8108 - val_loss: 0.3442 - val_accuracy: 0.8143
# Epoch 11/100
# 112/112 - 0s - loss: 0.3459 - accuracy: 0.8148 - val_loss: 0.3399 - val_accuracy: 0.8255
# Epoch 12/100
# 112/112 - 0s - loss: 0.3426 - accuracy: 0.8167 - val_loss: 0.3423 - val_accuracy: 0.8300
# Epoch 13/100
# 112/112 - 0s - loss: 0.3455 - accuracy: 0.8139 - val_loss: 0.3411 - val_accuracy: 0.8188
# Epoch 14/100
# 112/112 - 0s - loss: 0.3438 - accuracy: 0.8173 - val_loss: 0.3400 - val_accuracy: 0.8121
# Epoch 15/100
# 112/112 - 0s - loss: 0.3383 - accuracy: 0.8189 - val_loss: 0.3751 - val_accuracy: 0.7360
# Epoch 16/100
# 112/112 - 0s - loss: 0.3416 - accuracy: 0.8131 - val_loss: 0.3413 - val_accuracy: 0.8277
# Epoch 17/100
# 112/112 - 0s - loss: 0.3381 - accuracy: 0.8234 - val_loss: 0.3345 - val_accuracy: 0.8277
# Epoch 18/100
# 112/112 - 0s - loss: 0.3395 - accuracy: 0.8175 - val_loss: 0.3543 - val_accuracy: 0.7763
# Epoch 19/100
# 112/112 - 0s - loss: 0.3404 - accuracy: 0.8075 - val_loss: 0.3307 - val_accuracy: 0.8233
# Epoch 20/100
# 112/112 - 0s - loss: 0.3362 - accuracy: 0.8203 - val_loss: 0.3380 - val_accuracy: 0.8322
# Epoch 21/100
# 112/112 - 0s - loss: 0.3384 - accuracy: 0.8136 - val_loss: 0.3432 - val_accuracy: 0.8233
# Epoch 22/100
# 112/112 - 0s - loss: 0.3373 - accuracy: 0.8189 - val_loss: 0.3296 - val_accuracy: 0.8210
# Epoch 23/100
# 112/112 - 0s - loss: 0.3348 - accuracy: 0.8192 - val_loss: 0.3359 - val_accuracy: 0.8255
# Epoch 24/100
# 112/112 - 0s - loss: 0.3395 - accuracy: 0.8125 - val_loss: 0.3358 - val_accuracy: 0.8277
# Epoch 25/100
# 112/112 - 0s - loss: 0.3388 - accuracy: 0.8167 - val_loss: 0.3367 - val_accuracy: 0.8345
# Epoch 26/100
# 112/112 - 0s - loss: 0.3363 - accuracy: 0.8201 - val_loss: 0.3327 - val_accuracy: 0.8277
# Epoch 27/100
# 112/112 - 0s - loss: 0.3348 - accuracy: 0.8167 - val_loss: 0.3369 - val_accuracy: 0.8277
# Epoch 28/100
# 112/112 - 0s - loss: 0.3346 - accuracy: 0.8195 - val_loss: 0.3329 - val_accuracy: 0.8322
# Epoch 29/100
# 112/112 - 0s - loss: 0.3347 - accuracy: 0.8195 - val_loss: 0.3414 - val_accuracy: 0.7942
# Epoch 30/100
# 112/112 - 0s - loss: 0.3332 - accuracy: 0.8203 - val_loss: 0.3312 - val_accuracy: 0.8300
# Epoch 31/100
# 112/112 - 0s - loss: 0.3360 - accuracy: 0.8198 - val_loss: 0.3317 - val_accuracy: 0.8300
# Epoch 32/100
# 112/112 - 0s - loss: 0.3357 - accuracy: 0.8159 - val_loss: 0.3544 - val_accuracy: 0.7718
# Epoch 33/100
# 112/112 - 0s - loss: 0.3347 - accuracy: 0.8161 - val_loss: 0.3383 - val_accuracy: 0.8322
# Epoch 34/100
# 112/112 - 0s - loss: 0.3358 - accuracy: 0.8198 - val_loss: 0.3294 - val_accuracy: 0.8300
# Epoch 35/100
# 112/112 - 0s - loss: 0.3321 - accuracy: 0.8215 - val_loss: 0.3277 - val_accuracy: 0.8255
# Epoch 36/100
# 112/112 - 0s - loss: 0.3338 - accuracy: 0.8164 - val_loss: 0.3272 - val_accuracy: 0.8300
# Epoch 37/100
# 112/112 - 0s - loss: 0.3332 - accuracy: 0.8192 - val_loss: 0.3329 - val_accuracy: 0.8277
# Epoch 38/100
# 112/112 - 0s - loss: 0.3308 - accuracy: 0.8217 - val_loss: 0.3373 - val_accuracy: 0.8233
# Epoch 39/100
# 112/112 - 0s - loss: 0.3307 - accuracy: 0.8229 - val_loss: 0.3381 - val_accuracy: 0.8322
# Epoch 40/100
# 112/112 - 0s - loss: 0.3356 - accuracy: 0.8175 - val_loss: 0.3327 - val_accuracy: 0.8322
# Epoch 41/100
# 112/112 - 0s - loss: 0.3359 - accuracy: 0.8181 - val_loss: 0.3407 - val_accuracy: 0.7808
# Epoch 42/100
# 112/112 - 0s - loss: 0.3359 - accuracy: 0.8117 - val_loss: 0.3264 - val_accuracy: 0.8300
# Epoch 43/100
# 112/112 - 0s - loss: 0.3325 - accuracy: 0.8203 - val_loss: 0.3292 - val_accuracy: 0.8322
# Epoch 44/100
# 112/112 - 0s - loss: 0.3326 - accuracy: 0.8195 - val_loss: 0.3279 - val_accuracy: 0.8255
# Epoch 45/100
# 112/112 - 0s - loss: 0.3328 - accuracy: 0.8189 - val_loss: 0.3264 - val_accuracy: 0.8277
# Epoch 46/100
# 112/112 - 0s - loss: 0.3309 - accuracy: 0.8198 - val_loss: 0.3270 - val_accuracy: 0.8188
# Epoch 47/100
# 112/112 - 0s - loss: 0.3347 - accuracy: 0.8248 - val_loss: 0.3454 - val_accuracy: 0.7830
# Epoch 48/100
# 112/112 - 0s - loss: 0.3333 - accuracy: 0.8203 - val_loss: 0.3331 - val_accuracy: 0.8300
# Epoch 49/100
# 112/112 - 0s - loss: 0.3321 - accuracy: 0.8206 - val_loss: 0.3324 - val_accuracy: 0.8277
# Epoch 50/100
# 112/112 - 0s - loss: 0.3303 - accuracy: 0.8206 - val_loss: 0.3502 - val_accuracy: 0.7785
# Epoch 51/100
# 112/112 - 0s - loss: 0.3319 - accuracy: 0.8181 - val_loss: 0.3290 - val_accuracy: 0.8277
# Epoch 52/100
# 112/112 - 0s - loss: 0.3354 - accuracy: 0.8170 - val_loss: 0.3275 - val_accuracy: 0.8322
# Epoch 53/100
# 112/112 - 0s - loss: 0.3303 - accuracy: 0.8223 - val_loss: 0.3336 - val_accuracy: 0.8367
# Epoch 54/100
# 112/112 - 0s - loss: 0.3322 - accuracy: 0.8226 - val_loss: 0.3334 - val_accuracy: 0.8210
# Epoch 55/100
# 112/112 - 0s - loss: 0.3300 - accuracy: 0.8240 - val_loss: 0.3262 - val_accuracy: 0.8277
# Epoch 56/100
# 112/112 - 0s - loss: 0.3329 - accuracy: 0.8203 - val_loss: 0.3257 - val_accuracy: 0.8300
# Epoch 57/100
# 112/112 - 0s - loss: 0.3299 - accuracy: 0.8220 - val_loss: 0.3373 - val_accuracy: 0.8300
# Epoch 58/100
# 112/112 - 0s - loss: 0.3315 - accuracy: 0.8187 - val_loss: 0.3234 - val_accuracy: 0.8277
# Epoch 59/100
# 112/112 - 0s - loss: 0.3311 - accuracy: 0.8198 - val_loss: 0.3351 - val_accuracy: 0.8345
# Epoch 60/100
# 112/112 - 0s - loss: 0.3284 - accuracy: 0.8189 - val_loss: 0.3308 - val_accuracy: 0.8255
# Epoch 61/100
# 112/112 - 0s - loss: 0.3310 - accuracy: 0.8198 - val_loss: 0.3307 - val_accuracy: 0.8255
# Epoch 62/100
# 112/112 - 0s - loss: 0.3287 - accuracy: 0.8187 - val_loss: 0.3263 - val_accuracy: 0.8277
# Epoch 63/100
# 112/112 - 0s - loss: 0.3312 - accuracy: 0.8198 - val_loss: 0.3261 - val_accuracy: 0.8322
# Epoch 64/100
# 112/112 - 0s - loss: 0.3293 - accuracy: 0.8231 - val_loss: 0.3236 - val_accuracy: 0.8277
# Epoch 65/100
# 112/112 - 0s - loss: 0.3284 - accuracy: 0.8212 - val_loss: 0.3252 - val_accuracy: 0.8322
# Epoch 66/100
# 112/112 - 0s - loss: 0.3304 - accuracy: 0.8170 - val_loss: 0.3326 - val_accuracy: 0.8367
# Epoch 67/100
# 112/112 - 0s - loss: 0.3290 - accuracy: 0.8259 - val_loss: 0.3267 - val_accuracy: 0.8300
# Epoch 68/100
# 112/112 - 0s - loss: 0.3283 - accuracy: 0.8237 - val_loss: 0.3276 - val_accuracy: 0.8322
# Epoch 69/100
# 112/112 - 0s - loss: 0.3280 - accuracy: 0.8198 - val_loss: 0.3266 - val_accuracy: 0.8345
# Epoch 70/100
# 112/112 - 0s - loss: 0.3295 - accuracy: 0.8215 - val_loss: 0.3362 - val_accuracy: 0.8322
# Epoch 71/100
# 112/112 - 0s - loss: 0.3282 - accuracy: 0.8215 - val_loss: 0.3321 - val_accuracy: 0.8277
# Epoch 72/100
# 112/112 - 0s - loss: 0.3317 - accuracy: 0.8153 - val_loss: 0.3309 - val_accuracy: 0.8300
# Epoch 73/100
# 112/112 - 0s - loss: 0.3301 - accuracy: 0.8201 - val_loss: 0.3237 - val_accuracy: 0.8188
# Epoch 74/100
# 112/112 - 0s - loss: 0.3290 - accuracy: 0.8201 - val_loss: 0.3264 - val_accuracy: 0.8277
# Epoch 75/100
# 112/112 - 0s - loss: 0.3281 - accuracy: 0.8198 - val_loss: 0.3458 - val_accuracy: 0.8367
# Epoch 76/100
# 112/112 - 0s - loss: 0.3290 - accuracy: 0.8173 - val_loss: 0.3496 - val_accuracy: 0.7830
# Epoch 77/100
# 112/112 - 0s - loss: 0.3281 - accuracy: 0.8229 - val_loss: 0.3425 - val_accuracy: 0.8076
# Epoch 78/100
# 112/112 - 0s - loss: 0.3297 - accuracy: 0.8209 - val_loss: 0.3255 - val_accuracy: 0.8322
# Epoch 79/100
# 112/112 - 0s - loss: 0.3306 - accuracy: 0.8175 - val_loss: 0.3415 - val_accuracy: 0.8345
# Epoch 80/100
# 112/112 - 0s - loss: 0.3308 - accuracy: 0.8195 - val_loss: 0.3424 - val_accuracy: 0.7897
# Epoch 81/100
# 112/112 - 0s - loss: 0.3279 - accuracy: 0.8206 - val_loss: 0.3288 - val_accuracy: 0.8300
# Epoch 82/100
# 112/112 - 0s - loss: 0.3274 - accuracy: 0.8217 - val_loss: 0.3372 - val_accuracy: 0.8389
# Epoch 83/100
# 112/112 - 0s - loss: 0.3265 - accuracy: 0.8248 - val_loss: 0.3313 - val_accuracy: 0.8322
# Epoch 84/100
# 112/112 - 0s - loss: 0.3257 - accuracy: 0.8256 - val_loss: 0.3340 - val_accuracy: 0.8389
# Epoch 85/100
# 112/112 - 0s - loss: 0.3279 - accuracy: 0.8243 - val_loss: 0.3249 - val_accuracy: 0.8277
# Epoch 86/100
# 112/112 - 0s - loss: 0.3300 - accuracy: 0.8203 - val_loss: 0.3255 - val_accuracy: 0.8322
# Epoch 87/100
# 112/112 - 0s - loss: 0.3274 - accuracy: 0.8201 - val_loss: 0.3302 - val_accuracy: 0.8277
# Epoch 88/100
# 112/112 - 0s - loss: 0.3267 - accuracy: 0.8203 - val_loss: 0.3279 - val_accuracy: 0.8300
# Epoch 89/100
# 112/112 - 0s - loss: 0.3272 - accuracy: 0.8203 - val_loss: 0.3251 - val_accuracy: 0.8277
# Epoch 90/100
# 112/112 - 0s - loss: 0.3296 - accuracy: 0.8184 - val_loss: 0.3446 - val_accuracy: 0.8188
# Epoch 91/100
# 112/112 - 0s - loss: 0.3268 - accuracy: 0.8195 - val_loss: 0.3242 - val_accuracy: 0.8300
# Epoch 92/100
# 112/112 - 0s - loss: 0.3277 - accuracy: 0.8198 - val_loss: 0.3418 - val_accuracy: 0.8322
# Epoch 93/100
# 112/112 - 0s - loss: 0.3264 - accuracy: 0.8240 - val_loss: 0.3260 - val_accuracy: 0.8345
# Epoch 94/100
# 112/112 - 0s - loss: 0.3260 - accuracy: 0.8175 - val_loss: 0.3567 - val_accuracy: 0.7808
# Epoch 95/100
# 112/112 - 0s - loss: 0.3318 - accuracy: 0.8240 - val_loss: 0.3403 - val_accuracy: 0.8300
# Epoch 96/100
# 112/112 - 0s - loss: 0.3258 - accuracy: 0.8234 - val_loss: 0.3323 - val_accuracy: 0.8389
# Epoch 97/100
# 112/112 - 0s - loss: 0.3247 - accuracy: 0.8243 - val_loss: 0.3299 - val_accuracy: 0.8322
# Epoch 98/100
# 112/112 - 0s - loss: 0.3256 - accuracy: 0.8231 - val_loss: 0.3299 - val_accuracy: 0.8389
# Epoch 99/100
# 112/112 - 0s - loss: 0.3278 - accuracy: 0.8178 - val_loss: 0.3264 - val_accuracy: 0.8345
# Epoch 100/100
# 112/112 - 0s - loss: 0.3253 - accuracy: 0.8189 - val_loss: 0.3309 - val_accuracy: 0.8322

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

pred=ann.predict(test_inputs)

pred
# Out:
# array([[6.68531299e-01],
#        [1.00000000e+00],
#        [8.17738771e-01],
#        [3.40458333e-01],
#        [8.31088364e-01],
#        [3.69836271e-01],
#        [9.99232292e-01],
#        [9.13787425e-01],
#        [1.00000000e+00],
#        [9.99984264e-01],
#        [3.92430604e-01],
#        [1.00000000e+00],
#        [1.33113758e-37],
#        [5.74370003e-31],
#        [5.33663988e-01],
#        [0.00000000e+00],
#        [8.51418614e-01],
#        [8.63279343e-01],
#        [4.46160284e-19],
#        [2.62666017e-12],
#        [3.94846916e-01],
#        [9.99956727e-01],
#        [8.51631165e-04],
#        [4.02151704e-01],
#        [1.93714985e-13],
#        [3.01810414e-01],
#        [4.25433338e-01],
#        [4.07345235e-01],
#        [3.42351794e-01],
#        [2.35302001e-26],
#        [3.85770828e-01],
#        [5.00937089e-20],
#        [3.91900718e-01],
#        [3.50189060e-01],
#        [3.74423623e-01],
#        [3.82849842e-01],
#        [3.31799567e-01],
#        [4.67141340e-38],
#        [9.98606205e-01],
#        [7.00920820e-04],
#        [3.82849842e-01],
#        [8.35546196e-01],
#        [3.22796249e-17],
#        [9.99820590e-01],
#        [8.30278207e-11],
#        [5.28893232e-01],
#        [8.15431774e-01],
#        [9.99994516e-01],
#        [1.00000000e+00],
#        [9.81361270e-01],
#        [6.69974029e-01],
#        [9.89576399e-01],
#        [4.31299066e-23],
#        [3.16026399e-06],
#        [2.98137426e-01],
#        [3.64849865e-01],
#        [3.30600590e-01],
#        [8.82408679e-01],
#        [9.99731302e-01],
#        [1.00000000e+00],
#        [3.70670974e-01],
#        [5.04068613e-01],
#        [3.01810414e-01],
#        [4.91543919e-01],
#        [3.46000791e-01],
#        [2.48128579e-12],
#        [3.50556970e-01],
#        [3.85979652e-01],
#        [1.00000000e+00],
#        [3.79264057e-01],
#        [3.68528873e-01],
#        [2.21205056e-02],
#        [3.80933613e-01],
#        [3.82849842e-01],
#        [2.99021244e-01],
#        [9.99225020e-01],
#        [9.99990642e-01],
#        [3.21942389e-01],
#        [9.99911785e-01],
#        [3.40458333e-01],
#        [2.49633681e-32],
#        [3.40458333e-01],
#        [8.51117492e-01],
#        [0.00000000e+00],
#        [9.99931455e-01],
#        [1.23590231e-04],
#        [6.17347224e-14],
#        [3.34527969e-37],
#        [9.99533057e-01],
#        [1.84449644e-21],
#        [3.77234757e-01],
#        [5.09432375e-01],
#        [7.93280125e-01],
#        [9.99999881e-01],
#        [1.85483090e-16],
#        [3.40458333e-01],
#        [3.79589260e-01],
#        [3.40458333e-01],
#        [3.19990039e-01],
#        [1.00000000e+00],
#        [9.99996066e-01],
#        [3.19750965e-01],
#        [2.49356265e-28],
#        [3.69083613e-01],
#        [0.00000000e+00],
#        [3.01810414e-01],
#        [3.40458333e-01],
#        [9.99238849e-01],
#        [3.42351794e-01],
#        [6.76062276e-20],
#        [9.12475467e-01],
#        [0.00000000e+00],
#        [8.29785109e-01],
#        [9.28749502e-01],
#        [3.92430604e-01],
#        [3.52102101e-01],
#        [1.52898036e-14],
#        [3.82849842e-01],
#        [3.23943019e-01],
#        [3.70170027e-01],
#        [3.46426070e-01],
#        [1.13142323e-33],
#        [8.72205019e-01],
#        [9.95540023e-02],
#        [4.02151704e-01],
#        [8.39591622e-01],
#        [6.12699059e-27],
#        [9.98945892e-01],
#        [9.97085869e-01],
#        [7.09905744e-01],
#        [9.99642372e-01],
#        [9.99931455e-01],
#        [3.54248106e-01],
#        [6.56113029e-03],
#        [8.20031762e-01],
#        [1.00000000e+00],
#        [8.07537317e-01],
#        [9.99619484e-01],
#        [3.73200119e-01],
#        [8.80699039e-01],
#        [1.00000000e+00],
#        [9.33262944e-01],
#        [9.77313876e-01],
#        [9.99709368e-01],
#        [4.02151704e-01],
#        [6.81481838e-01],
#        [3.60221922e-01],
#        [3.40458333e-01],
#        [0.00000000e+00],
#        [8.68373334e-01],
#        [7.61190295e-01],
#        [9.97611761e-01],
#        [8.27560663e-01],
#        [8.37821662e-01],
#        [7.59011149e-01],
#        [8.94373536e-01],
#        [5.08712173e-01],
#        [2.20835209e-04],
#        [3.82849842e-01],
#        [1.00000000e+00],
#        [7.96085954e-01],
#        [3.74594331e-01],
#        [6.48993790e-18],
#        [5.23268163e-01],
#        [7.16287613e-01],
#        [3.82849842e-01],
#        [9.99862432e-01],
#        [1.00000000e+00],
#        [9.99361873e-01],
#        [1.50802629e-21],
#        [8.42761695e-02],
#        [8.23505104e-01],
#        [2.98688948e-01],
#        [0.00000000e+00],
#        [3.78015786e-01],
#        [9.99798059e-01],
#        [7.78647006e-01],
#        [9.99997616e-01],
#        [2.51558561e-07],
#        [3.40458333e-01],
#        [8.53908539e-01],
#        [3.01810414e-01],
#        [7.25932717e-01],
#        [3.50189060e-01],
#        [2.65369530e-28],
#        [0.00000000e+00],
#        [9.99998748e-01],
#        [8.56930017e-01],
#        [8.94163847e-01],
#        [3.30600590e-01],
#        [1.21674476e-10],
#        [5.04619300e-01],
#        [3.01810414e-01],
#        [3.01810414e-01],
#        [1.04496479e-02],
#        [9.99982834e-01],
#        [3.59722793e-01],
#        [9.95998621e-01],
#        [3.96076858e-01],
#        [9.99982834e-01],
#        [3.82849842e-01],
#        [5.39308497e-34],
#        [3.80742222e-01],
#        [4.15693671e-01],
#        [7.65471220e-01],
#        [3.84268761e-01]], dtype=float32)

# %%
pred=pred>.5
cm=confusion_matrix(test_targets,pred)
print(cm)
# Out:
# [[203  23]
#  [ 56 166]]

# %%
score=accuracy_score(test_targets,pred)
print(score)
# Out:
# 0.8236607142857143
